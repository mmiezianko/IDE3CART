# %%
import csv
import numpy as np
import pandas as pd
from decision_tree.grow_decision_tree import grow_tree, plot, prune, predict
from decision_tree.open_file import loadCSV
import matplotlib.pyplot as plt
import networkx as nx

# %%
trainingData3 = loadCSV('../data/iris.csv') # demo data from matlab



decisionTree3 = grow_tree(trainingData3)
plot(decisionTree3)

# %%
def get_hash_dict(d_tree, hash_dict):
    if d_tree.value is not None:
        hash_dict[d_tree.__hash__()] = [d_tree.branch_with_value.__hash__(), d_tree.branch_with_others.__hash__()]
        get_hash_dict(d_tree.branch_with_value,hash_dict)
        get_hash_dict(d_tree.branch_with_others,hash_dict)
def get_neighborhood_list(d_tree):
    dict = {}
    get_hash_dict(d_tree, dict)
    print(dict)
    values = [k for k in dict.keys()]
    for v in dict.values():
        values.extend(v)
    hashes = set(values)
    hash_to_int = {k:i for i,k in enumerate(hashes)}
    print(hash_to_int)
    neighborhood_list = {}
    for k,v in dict.items():
        neighborhood_list[hash_to_int[k]]=[hash_to_int[v[0]], hash_to_int[v[1]]]
    print(neighborhood_list)
    return neighborhood_list

def draw_graph(nb_list):
    G = nx.Graph()
    G.add_nodes_from(nb_list.keys())
    for k, v in nb_list.items():
        G.add_edge(k,v[0])
        G.add_edge(k,v[1])
    plt.subplot(1)
    print("piniting...")
    nx.draw_shell(G, with_labels=True)
draw_graph(get_neighborhood_list(decisionTree3))

# %%
trainingData = loadCSV('../notebooks/dane.csv') # demo data from matlab



decisionTree = grow_tree(trainingData)
plot(decisionTree)
# Out:
# Column 1: x == czasowki?
# yes -> Column 0: x == letnio?
# 		yes -> Column 2: x == <3?
# 				yes -> Column 4: x == zmeczony?
# 						yes -> Column 3: x == kobieta?
# 								yes -> {'skaly': 1}
# 								no  -> {'dom': 1}
# 2
# 						no  -> {'skaly': 4}
# 4
# 				no  -> Column 4: x == srednie?
# 						yes -> Column 2: x == 3-10?
# 								yes -> Column 3: x == kobieta?
# 										yes -> {'skaly': 1}
# 										no  -> {'dom': 1}
# 7
# 								no  -> {'dom': 2}
# 9
# 						no  -> {'skaly': 4, 'dom': 4}
# 11
# 12
# 		no  -> Column 0: x == zimno?
# 				yes -> Column 4: x == zmeczony?
# 						yes -> Column 3: x == kobieta?
# 								yes -> Column 2: x == <3?
# 										yes -> {'skaly': 1}
# 										no  -> Column 2: x == 3-10?
# 												yes -> {'scianka': 1}
# 												no  -> {'dom': 1}
# 16
# 17
# 								no  -> {'dom': 3}
# 19
# 						no  -> Column 4: x == wypoczęty?
# 								yes -> Column 2: x == 3-10?
# 										yes -> {'skaly': 2}
# 										no  -> {'dom': 2, 'skaly': 2}
# 22
# 								no  -> Column 2: x == 3-10?
# 										yes -> {'dom': 2}
# 										no  -> {'dom': 2, 'skaly': 2}
# 25
# 26
# 27
# 				no  -> Column 2: x == >10?
# 						yes -> Column 4: x == zmeczony?
# 								yes -> Column 0: x == goraco?
# 										yes -> Column 3: x == kobieta?
# 												yes -> {'scianka': 1}
# 												no  -> {'skaly': 1}
# 30
# 										no  -> {'skaly': 2}
# 32
# 								no  -> Column 0: x == mrozno?
# 										yes -> Column 3: x == kobieta?
# 												yes -> Column 4: x == wypoczęty?
# 														yes -> {'skaly': 1}
# 														no  -> {'dom': 1}
# 35
# 												no  -> {'scianka': 2}
# 37
# 										no  -> Column 3: x == kobieta?
# 												yes -> {'scianka': 2}
# 												no  -> Column 4: x == wypoczęty?
# 														yes -> {'scianka': 1}
# 														no  -> {'skaly': 1}
# 41
# 42
# 43
# 44
# 						no  -> Column 4: x == zmeczony?
# 								yes -> Column 0: x == goraco?
# 										yes -> {'dom': 4}
# 										no  -> Column 2: x == <3?
# 												yes -> {'scianka': 2}
# 												no  -> Column 3: x == kobieta?
# 														yes -> {'scianka': 1}
# 														no  -> {'dom': 1}
# 49
# 50
# 51
# 								no  -> Column 0: x == goraco?
# 										yes -> Column 2: x == <3?
# 												yes -> {'dom': 2, 'skaly': 2}
# 												no  -> Column 3: x == kobieta?
# 														yes -> {'skaly': 2}
# 														no  -> Column 4: x == wypoczęty?
# 																yes -> {'scianka': 1}
# 																no  -> {'skaly': 1}
# 56
# 57
# 58
# 										no  -> Column 4: x == srednie?
# 												yes -> {'skaly': 2, 'scianka': 2}
# 												no  -> Column 2: x == <3?
# 														yes -> {'skaly': 2}
# 														no  -> Column 3: x == kobieta?
# 																yes -> {'dom': 1}
# 																no  -> {'skaly': 1}
# 63
# 64
# 65
# 66
# 67
# 68
# 69
# 70
# no  -> Column 0: x == letnio?
# 		yes -> Column 4: x == zmeczony?
# 				yes -> Column 3: x == kobieta?
# 						yes -> Column 1: x == lina?
# 								yes -> {'scianka': 3}
# 								no  -> Column 2: x == <3?
# 										yes -> {'scianka': 1}
# 										no  -> Column 2: x == 3-10?
# 												yes -> {'dom': 1}
# 												no  -> {'skaly': 1}
# 75
# 76
# 77
# 						no  -> Column 2: x == >10?
# 								yes -> {'skaly': 2}
# 								no  -> {'skaly': 2, 'scianka': 2}
# 80
# 81
# 				no  -> Column 2: x == <3?
# 						yes -> Column 1: x == lina?
# 								yes -> {'dom': 4}
# 								no  -> Column 3: x == kobieta?
# 										yes -> {'scianka': 2}
# 										no  -> Column 4: x == wypoczęty?
# 												yes -> {'scianka': 1}
# 												no  -> {'dom': 1}
# 86
# 87
# 88
# 						no  -> Column 1: x == lina?
# 								yes -> Column 4: x == wypoczęty?
# 										yes -> Column 2: x == 3-10?
# 												yes -> Column 3: x == kobieta?
# 														yes -> {'skaly': 1}
# 														no  -> {'scianka': 1}
# 91
# 												no  -> Column 3: x == kobieta?
# 														yes -> {'scianka': 1}
# 														no  -> {'dom': 1}
# 94
# 95
# 										no  -> {'scianka': 4}
# 97
# 								no  -> Column 4: x == wypoczęty?
# 										yes -> {'scianka': 4}
# 										no  -> Column 3: x == kobieta?
# 												yes -> {'dom': 2}
# 												no  -> {'skaly': 2}
# 101
# 102
# 103
# 104
# 105
# 		no  -> Column 2: x == <3?
# 				yes -> Column 0: x == mrozno?
# 						yes -> Column 3: x == kobieta?
# 								yes -> Column 1: x == lina?
# 										yes -> {'scianka': 3}
# 										no  -> Column 4: x == zmeczony?
# 												yes -> {'skaly': 1}
# 												no  -> Column 4: x == wypoczęty?
# 														yes -> {'dom': 1}
# 														no  -> {'scianka': 1}
# 110
# 111
# 112
# 								no  -> Column 4: x == wypoczęty?
# 										yes -> Column 1: x == lina?
# 												yes -> {'scianka': 1}
# 												no  -> {'skaly': 1}
# 115
# 										no  -> {'skaly': 4}
# 117
# 118
# 						no  -> Column 4: x == wypoczęty?
# 								yes -> Column 1: x == bouldering?
# 										yes -> Column 0: x == goraco?
# 												yes -> {'scianka': 2}
# 												no  -> Column 3: x == kobieta?
# 														yes -> {'skaly': 1}
# 														no  -> {'dom': 1}
# 122
# 123
# 										no  -> Column 0: x == goraco?
# 												yes -> {'skaly': 2}
# 												no  -> Column 3: x == kobieta?
# 														yes -> {'scianka': 1}
# 														no  -> {'skaly': 1}
# 127
# 128
# 129
# 								no  -> Column 3: x == kobieta?
# 										yes -> Column 0: x == goraco?
# 												yes -> Column 1: x == lina?
# 														yes -> {'dom': 2}
# 														no  -> Column 4: x == zmeczony?
# 																yes -> {'scianka': 1}
# 																no  -> {'skaly': 1}
# 133
# 134
# 												no  -> Column 1: x == lina?
# 														yes -> Column 4: x == zmeczony?
# 																yes -> {'skaly': 1}
# 																no  -> {'dom': 1}
# 137
# 														no  -> {'dom': 2}
# 139
# 140
# 										no  -> Column 1: x == lina?
# 												yes -> Column 0: x == goraco?
# 														yes -> Column 4: x == zmeczony?
# 																yes -> {'dom': 1}
# 																no  -> {'skaly': 1}
# 143
# 														no  -> Column 4: x == zmeczony?
# 																yes -> {'scianka': 1}
# 																no  -> {'dom': 1}
# 146
# 147
# 												no  -> {'skaly': 2, 'scianka': 2}
# 149
# 150
# 151
# 152
# 				no  -> Column 3: x == kobieta?
# 						yes -> Column 4: x == zmeczony?
# 								yes -> Column 0: x == goraco?
# 										yes -> Column 1: x == lina?
# 												yes -> Column 2: x == 3-10?
# 														yes -> {'dom': 1}
# 														no  -> {'skaly': 1}
# 155
# 												no  -> Column 2: x == 3-10?
# 														yes -> {'skaly': 1}
# 														no  -> {'scianka': 1}
# 158
# 159
# 										no  -> Column 0: x == mrozno?
# 												yes -> {'skaly': 2, 'dom': 2}
# 												no  -> Column 1: x == lina?
# 														yes -> {'skaly': 2}
# 														no  -> Column 2: x == 3-10?
# 																yes -> {'skaly': 1}
# 																no  -> {'dom': 1}
# 164
# 165
# 166
# 167
# 								no  -> Column 2: x == 3-10?
# 										yes -> Column 0: x == mrozno?
# 												yes -> Column 1: x == lina?
# 														yes -> {'scianka': 2}
# 														no  -> Column 4: x == wypoczęty?
# 																yes -> {'dom': 1}
# 																no  -> {'scianka': 1}
# 171
# 172
# 												no  -> Column 4: x == wypoczęty?
# 														yes -> Column 0: x == goraco?
# 																yes -> Column 1: x == lina?
# 																		yes -> {'scianka': 1}
# 																		no  -> {'skaly': 1}
# 175
# 																no  -> {'scianka': 2}
# 177
# 														no  -> {'dom': 2, 'skaly': 2}
# 179
# 180
# 										no  -> Column 4: x == wypoczęty?
# 												yes -> Column 0: x == goraco?
# 														yes -> {'dom': 2}
# 														no  -> Column 0: x == zimno?
# 																yes -> Column 1: x == lina?
# 																		yes -> {'dom': 1}
# 																		no  -> {'skaly': 1}
# 184
# 																no  -> {'skaly': 2}
# 186
# 187
# 												no  -> Column 0: x == goraco?
# 														yes -> {'scianka': 2}
# 														no  -> Column 0: x == zimno?
# 																yes -> Column 1: x == lina?
# 																		yes -> {'scianka': 1}
# 																		no  -> {'dom': 1}
# 191
# 																no  -> {'dom': 2}
# 193
# 194
# 195
# 196
# 197
# 						no  -> Column 2: x == 3-10?
# 								yes -> Column 0: x == goraco?
# 										yes -> {'dom': 6}
# 										no  -> Column 4: x == srednie?
# 												yes -> Column 0: x == zimno?
# 														yes -> Column 1: x == lina?
# 																yes -> {'scianka': 1}
# 																no  -> {'dom': 1}
# 201
# 														no  -> {'scianka': 2}
# 203
# 												no  -> Column 0: x == mrozno?
# 														yes -> Column 1: x == lina?
# 																yes -> Column 4: x == zmeczony?
# 																		yes -> {'scianka': 1}
# 																		no  -> {'dom': 1}
# 206
# 																no  -> Column 4: x == zmeczony?
# 																		yes -> {'dom': 1}
# 																		no  -> {'skaly': 1}
# 209
# 210
# 														no  -> Column 1: x == lina?
# 																yes -> {'dom': 2}
# 																no  -> Column 4: x == zmeczony?
# 																		yes -> {'dom': 1}
# 																		no  -> {'scianka': 1}
# 214
# 215
# 216
# 217
# 218
# 								no  -> Column 1: x == bouldering?
# 										yes -> Column 0: x == mrozno?
# 												yes -> Column 4: x == zmeczony?
# 														yes -> {'scianka': 1}
# 														no  -> {'dom': 2}
# 221
# 												no  -> Column 4: x == srednie?
# 														yes -> {'scianka': 2}
# 														no  -> {'scianka': 2, 'dom': 2}
# 224
# 225
# 										no  -> Column 0: x == zimno?
# 												yes -> Column 4: x == srednie?
# 														yes -> {'skaly': 1}
# 														no  -> {'dom': 2}
# 228
# 												no  -> Column 0: x == goraco?
# 														yes -> Column 4: x == zmeczony?
# 																yes -> {'skaly': 1}
# 																no  -> {'scianka': 2}
# 231
# 														no  -> Column 4: x == zmeczony?
# 																yes -> {'scianka': 1}
# 																no  -> {'skaly': 2}
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242

# %%
prune(decisionTree3, 0.5, noticication=True) # notify, when a branch is pruned (one time in this example)
plot(decisionTree3)
print('###')
print(predict([6.0, 2.2, 5.0, 1.5], decisionTree3))

# %% [markdown]
# # Drzewa decyzyjne
#
# Drzewo decyzyjne to struktura danych zorganizowanych w drzewo, w którym
# z każdego węzła (oprócz liści) wychodzą gałęzie reprezentujące poszczególne wartości
# atrybutu danych pełniącego funkcję klasyfikatora.
#
# Podstawowym algorytmem budowania drzewa decyzyjnego jest algorytm ID3, bazujący na entropii
# informacyjnej i wartości zysku informacyjnego poszczególnych atrybutów.
#
# ## Elementy teorii informacji
#
# Przedmiotem teorii informacji jest kwantyfikowanie informacji, czyli ujmowanie jej w sposób
# ilościowy, a także detale związane z jej przechowywaniem i przesyłaniem. Poniżej wyjaśnimy podstawowe
# dwa pojęcia, na których opiera się konstruowanie drzew decyzyjnych za pomocą algorytmu ID3.
#
# ### Entropia
#
# W celu zbudowania drzewa decyzyjnego, będziemy musieli określić zadawane pytania,
# a także ustawić je w odpowieniej kolejności. Na każdym etapie drzewa będą znajdowały
# się jakieś możliwości, które wyelminowaliśmy, i inne, które czekają na podział. Każde
# pytanie dzieli pozostałe możliwości zgodnie z odpowiedzią.
#
# Najlepiej byłoby, gdybyśmy zadawali pytania, które dają odpowiedzi zawierające dużo
# informacji na temat tego, co nasze drzewo powinno przewidzieć. "Ilość wnoszonych informacji"
# można określić właśnie za pomocą entropii, czyli swoistej miary niepewności związanej z danymi.
#
# Ogólnie rzecz biorąc - dyby wszystkie elementy danego zbioru należały do jednej klasy,
# to nie ma żadnej niepewności, a więc entropia byłaby niska. W przypadku równego
# rozdziału elementów pomiędzy klasy mamy dużą niepewność, a więc wysoką entropię.
#
# Jeżeli p określa część danych oznaczoną etykietami wskazującymi na przynależność do danej
# klasy, to entropię możemy opisać następującym równaniem:
#
# ![](https://miro.medium.com/max/1094/1*voRgqFZhfko4ZfG3odSK_Q.png)
#
# Wzór ten zakłada, że 0 log 0 = 0.
#
# Co więcej, przyjmujemy również, że kaźdy czynnik $ -p_{i} log_{2} p_{i} $ jest wartością
# nieujemną i bliską zeru dokładnie wtedy, gdy wartość $ -p_{i} $ jest zbliżona do 0
# lub 1, co obrazuje poniższy wykres.
#
# ![](https://s3-ap-southeast-1.amazonaws.com/he-public-data/Entropydfcb350.jpg)
